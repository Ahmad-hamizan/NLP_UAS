# %%
pip install google-play-scraper
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ### Import Library

# %%
import pandas as pd
from google_play_scraper import Sort, reviews

# %% [markdown]
# ### Crawl Data

# %%
print("Memulai scraping data Gojek")

gojek_reviews, _ = reviews(
    'com.gojek.app',
    lang='id',
    country='id',
    sort=Sort.NEWEST,
    count=10000
)

df_gojek = pd.DataFrame(gojek_reviews)

df_gojek['apps'] = 'Gojek'

print(
    f"Selesai! Berhasil mengambil {len(df_gojek)} ulasan Gojek."
)
# Out:
# Memulai scraping data Gojek
# Selesai! Berhasil mengambil 10000 ulasan Gojek.

# %%
print("Memulai scraping data Grab")

grab_reviews, _ = reviews(
    'com.grabtaxi.passenger',
    lang='id',
    country='id',
    sort=Sort.NEWEST,
    count=10000
)

df_grab = pd.DataFrame(grab_reviews)

df_grab['apps'] = 'Grab'

print(
    f"Selesai! Berhasil mengambil {len(df_grab)} ulasan Grab."
)
# Out:
# Memulai scraping data Grab
# Selesai! Berhasil mengambil 10000 ulasan Grab.

# %% [markdown]
# ### Menyimpan data

# %%
df_gojek.to_csv('gojek_reviews.csv', index=False)
df_grab.to_csv('grab_reviews.csv', index=False)
