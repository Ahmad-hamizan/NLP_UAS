# %% [markdown]
# ## GOJEK

# %% [markdown]
# ### Import Library

# %%
import pandas as pd
import re

# %% [markdown]
# ### Load Dataset

# %%
df_gojek = pd.read_csv('gojek_reviews.csv')
df_gojek.head()
# Out:
#                                reviewId         userName  \
# 0  6083605b-7faa-4eae-aa8c-cbff9c9f5398  Pengguna Google
# 1  e4fb4a88-e8ef-42f1-989e-8ad1bb195c36  Pengguna Google
# 2  0bd033c1-d662-4c10-9ccc-5f04418060e8  Pengguna Google
# 3  3841810d-ac6a-4046-9f65-370457076d57  Pengguna Google
# 4  f5e00323-0665-4f48-8bbc-7636a499ed67  Pengguna Google
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/EGemoI2N...
# 1  https://play-lh.googleusercontent.com/EGemoI2N...
# 2  https://play-lh.googleusercontent.com/EGemoI2N...
# 3  https://play-lh.googleusercontent.com/EGemoI2N...
# 4  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                              content  score  thumbsUpCount  \
# 0  ga jelas, bertahun-tahun pake tiba-tiba dibila...      1              0
# 1  semakin kesini kok lebih parah dari lintah dar...      1              0
# 2                                         kelas king      5              0
# 3                                              ramah      5              0
# 4                                          memuaskan      5              0
#
#   reviewCreatedVersion                   at  \
# 0                  NaN  2026-06-21 08:55:15
# 1               5.63.1  2026-06-21 08:39:41
# 2                  NaN  2026-06-21 08:36:28
# 3               5.63.1  2026-06-21 08:29:51
# 4               5.61.1  2026-06-21 08:13:56
#
#                                         replyContent            repliedAt  \
# 0  Hai Kak Ahmad, mohon maaf atas ketidaknyamanny...  2026-06-21 09:17:57
# 1  Hai Kak Muhlas, terima kasih atas ulasannya da...  2026-06-21 09:11:08
# 2                                                NaN                  NaN
# 3                                                NaN                  NaN
# 4                                                NaN                  NaN
#
#   appVersion   apps
# 0        NaN  Gojek
# 1     5.63.1  Gojek
# 2        NaN  Gojek
# 3     5.63.1  Gojek
# 4     5.61.1  Gojek

# %% [markdown]
# ### EDA (Exploratory Data Analis)

# %%
num_gojek = len(df_gojek)
print(f"Jumlah ulasan dalam dataframe {num_gojek} data")
# Out:
# Jumlah ulasan dalam dataframe 10000 data

# %%
df_gojek_test = df_gojek.copy()
df_gojek_test
# Out:
#                                   reviewId          userName  \
# 0     6083605b-7faa-4eae-aa8c-cbff9c9f5398   Pengguna Google
# 1     e4fb4a88-e8ef-42f1-989e-8ad1bb195c36   Pengguna Google
# 2     0bd033c1-d662-4c10-9ccc-5f04418060e8   Pengguna Google
# 3     3841810d-ac6a-4046-9f65-370457076d57   Pengguna Google
# 4     f5e00323-0665-4f48-8bbc-7636a499ed67   Pengguna Google
# ...                                    ...               ...
# 9995  2553e26b-d7c5-444a-8d1d-bd41bcb429f6   Novita Miradewi
# 9996  be8d2909-54f3-42ed-91d7-f2e6ee9f20c1        Arif Bowox
# 9997  0fec53f4-642b-4501-a678-5341ff6de6ba          Febri Cs
# 9998  1758ee03-5b00-4cc1-9429-7a01475d32c7  Moses Sudanartha
# 9999  7616ec3b-90ea-4270-9036-76cd619f9b68            Supena
#
#                                               userImage  \
# 0     https://play-lh.googleusercontent.com/EGemoI2N...
# 1     https://play-lh.googleusercontent.com/EGemoI2N...
# 2     https://play-lh.googleusercontent.com/EGemoI2N...
# 3     https://play-lh.googleusercontent.com/EGemoI2N...
# 4     https://play-lh.googleusercontent.com/EGemoI2N...
# ...                                                 ...
# 9995  https://play-lh.googleusercontent.com/a/ACg8oc...
# 9996  https://play-lh.googleusercontent.com/a/ACg8oc...
# 9997  https://play-lh.googleusercontent.com/a/ACg8oc...
# 9998  https://play-lh.googleusercontent.com/a-/ALV-U...
# 9999  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                                                 content  score  thumbsUpCount  \
# 0     ga jelas, bertahun-tahun pake tiba-tiba dibila...      1              0
# 1     semakin kesini kok lebih parah dari lintah dar...      1              0
# 2                                            kelas king      5              0
# 3                                                 ramah      5              0
# 4                                             memuaskan      5              0
# ...                                                 ...    ...            ...
# 9995                                              bagus      5              0
# 9996                                        baik sekali      5              0
# 9997               segini dlu deh klo bagus tambah lagi      2              0
# 9998  Drivernya tolong jangan memainkan orderan. dit...      1              3
# 9999                                       terima kasih      5              0
#
#      reviewCreatedVersion                   at  \
# 0                     NaN  2026-06-21 08:55:15
# 1                  5.63.1  2026-06-21 08:39:41
# 2                     NaN  2026-06-21 08:36:28
# 3                  5.63.1  2026-06-21 08:29:51
# 4                  5.61.1  2026-06-21 08:13:56
# ...                   ...                  ...
# 9995               5.53.2  2026-04-03 09:02:32
# 9996                  NaN  2026-04-03 08:54:33
# 9997                  NaN  2026-04-03 08:44:03
# 9998               5.54.1  2026-04-03 08:41:20
# 9999               5.54.1  2026-04-03 08:39:56
#
#                                            replyContent            repliedAt  \
# 0     Hai Kak Ahmad, mohon maaf atas ketidaknyamanny...  2026-06-21 09:17:57
# 1     Hai Kak Muhlas, terima kasih atas ulasannya da...  2026-06-21 09:11:08
# 2                                                   NaN                  NaN
# 3                                                   NaN                  NaN
# 4                                                   NaN                  NaN
# ...                                                 ...                  ...
# 9995                                                NaN                  NaN
# 9996                                                NaN                  NaN
# 9997                                                NaN                  NaN
# 9998  Hai Kak Moses, mohon maaf atas ketidaknyamanan...  2026-04-03 09:09:26
# 9999                                                NaN                  NaN
#
#      appVersion   apps
# 0           NaN  Gojek
# 1        5.63.1  Gojek
# 2           NaN  Gojek
# 3        5.63.1  Gojek
# 4        5.61.1  Gojek
# ...         ...    ...
# 9995     5.53.2  Gojek
# 9996        NaN  Gojek
# 9997        NaN  Gojek
# 9998     5.54.1  Gojek
# 9999     5.54.1  Gojek
#
# [10000 rows x 12 columns]

# %%
pd.set_option('display.max_colwidth', None)
df_gojek_test['content'].head(5)
# Out:
# 0                                    ga jelas, bertahun-tahun pake tiba-tiba dibilang pelanggaran promo. padahal mereka sendiri yang munculin promo di app di pake malah dibilang melanggar
# 1    semakin kesini kok lebih parah dari lintah darat. disaat semua kebutuhan naik perawatan kendaraan juga naik tarif ke driver malah turun. semoga Allah memberikan kalian hidayah aamiin
# 2                                                                                                                                                                                kelas king
# 3                                                                                                                                                                                     ramah
# 4                                                                                                                                                                                 memuaskan
# Name: content, dtype: object

# %%
# Cek missing value
print(f"Jumlah missing value pada kolom 'content': {df_gojek['content'].isnull().sum()}")
# Out:
# Jumlah missing value pada kolom 'content': 0

# %% [markdown]
# ### Preprocesing

# %% [markdown]
# ##### Import Stopword Indonesia

# %%
import requests
stopwords_url = "https://raw.githubusercontent.com/louisowen6/NLP_bahasa_resources/master/combined_stop_words.txt"

response = requests.get(stopwords_url)

stopwords = response.text.splitlines()

stopwords = set(stopwords)

print(list(stopwords)[:10])
# Out:
# ['persoalan', 'baru', 'masing', 'ibarat', 'ujar', 'serta', 'semaunya', 'sesama', 'selama', 'termasuk']

# %%
kata_negasi = ['tidak', 'bukan', 'ga', 'gk', 'jangan']
for kata in kata_negasi:
    if kata in stopwords:
        stopwords.remove(kata)

# %% [markdown]
# ##### Import Slang Indonesia

# %%
import json

slang_url = "https://raw.githubusercontent.com/louisowen6/NLP_bahasa_resources/master/combined_slang_words.txt"

response = requests.get(slang_url)

kamus_slang_custom = response.json()

kamus_slang_custom.update({
    'tbtb': 'tiba tiba',
    'gk': 'tidak',
    'kdng': 'kadang'
})

print("Total kata di kamus baru:", len(kamus_slang_custom))
print("Contoh isi kamus (tbtb):", kamus_slang_custom['tbtb'])
# Out:
# Total kata di kamus baru: 1021
# Contoh isi kamus (tbtb): tiba tiba

# %% [markdown]
# #### Cleaning

# %%
def clean_string(text):
    text = str(text)

    # 1. Remove Metadata & Footer Removal
    text = text.strip()

    # 2. Remove URL
    text = re.sub(r'https?://\S+|www\.\S+', ' ', text)

    # 3. Lowercase
    text = text.lower()

    # 4. Remove Numbers
    text = re.sub(r'\d+', ' ', text)

    # 5. Remove Punctuation (Menghapus tanda baca & simbol/emoji)
    text = re.sub(r'[^a-z\s]', ' ', text)

    # 6. Merapikan spasi berlebih hasil pembersihan
    text = ' '.join(text.split())

    return text

# %%
# Pembersihan Berbasis Kata (Tokens)

def process_tokens(cleaned_sentence):
    text = str(cleaned_sentence).lower()
    # Tokenization
    tokens = text.split()

    final_tokens = []
    for token in tokens:
        token = token.strip()

        # Normalisasi Slang
        if token in kamus_slang_custom:
            token = kamus_slang_custom[token]

        # Stopword Removal
        if token not in stopwords:
            final_tokens.append(token)

    # Mengembalikan hasil akhir dalam bentuk kalimat bersih atau list token
    return ' '.join(final_tokens)

# %%
# Membersihkan String
df_gojek_test['step1_string'] = df_gojek_test['content'].apply(clean_string)

# Olah token dan normalisasinya
df_gojek_test['clean_content'] = df_gojek_test['step1_string'].apply(process_tokens)

# Perbandingannya
print(df_gojek_test[['content', 'clean_content']].head(100))
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 content  \
# 0                                                                                                                                                                                                                                                                                                                                                                ga jelas, bertahun-tahun pake tiba-tiba dibilang pelanggaran promo. padahal mereka sendiri yang munculin promo di app di pake malah dibilang melanggar
# 1                                                                                                                                                                                                                                                                                                                                semakin kesini kok lebih parah dari lintah darat. disaat semua kebutuhan naik perawatan kendaraan juga naik tarif ke driver malah turun. semoga Allah memberikan kalian hidayah aamiin
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            kelas king
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 ramah
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             memuaskan
# ..                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# 95                                                                                                                                                                                                                                                                                                                                                                                                                     desain simple gk membingungkan,pelayanan oke,cocok buat siapa aja dan yang pasti BUATAN NEGRI🔥🔥🔥
# 96                                                                                                                                                                                                                                                                                                                                                                                                                                   Ayolah jangan bikin iklan d aplikasi lain yang gk bisa d skip. ganggu banget !!!!!
# 97  Selama ini jujur saya sangat puas dengan gojek, membantu ketika saya bepergian karena saya seringkali bepergian menggunakan umum. tetapi hal menyebalkan terjadi, ketika saya sedang mendengarkan sesuatu diaplikasi lain dan hp saya taruh tas, ntah gimana ceritanya tbtb ada pesanan gofood yg masuk tanpa konfirmasi apapun. gak ada masukan pin atau sejenisnya. saya setelah buka hp tbtb udh ada pesanan. sekarang mau dibatalkan gak bisa, alhasil mau gak mau harus di bayar. Thanks for bad experiencenya
# 98                                                                                                                                                                                                                                                                                                                                                                                                                                                     enak sih kalo mager tinggal pesen aja, tapi ongkirnya kdng mahal
# 99                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  top
#
#                                                                                                                                                                                                                                                                                                 clean_content
# 0                                                                                                                                                                                                                    ga bertahun pakai dibilang pelanggaran promo munculin promo app pakai dibilang melanggar
# 1                                                                                                                                                                                               kesini parah lintah darat disaat kebutuhan perawatan kendaraan tarif driver turun semoga allah hidayah aamiin
# 2                                                                                                                                                                                                                                                                                                  kelas king
# 3                                                                                                                                                                                                                                                                                                       ramah
# 4                                                                                                                                                                                                                                                                                                   memuaskan
# ..                                                                                                                                                                                                                                                                                                        ...
# 95                                                                                                                                                                                                                                         desain simple tidak membingungkan pelayanan oke cocok buatan negri
# 96                                                                                                                                                                                                                                                ayolah jangan bikin iklan aplikasi tidak skip ganggu banget
# 97  jujur puas gojek bepergian seringkali bepergian menggunakan menyebalkan mendengarkan diaplikasi hp taruh tas ntah ceritanya tiba tiba pesanan gofood masuk konfirmasi apapun gak masukan pin sejenisnya buka hp tiba tiba udh pesanan dibatalkan gak alhasil gak bayar terima kasih for bad experiencenya
# 98                                                                                                                                                                                                                                                                enak sih mager pesen ongkirnya kadang mahal
# 99                                                                                                                                                                                                                                                                                                        top
#
# [100 rows x 2 columns]

# %% [markdown]
# #### Labeling

# %%
# !pip install vaderSentiment deep-translator
# Out:
# Collecting vaderSentiment
#   Downloading vaderSentiment-3.3.2-py2.py3-none-any.whl.metadata (572 bytes)
# Collecting deep-translator
#   Downloading deep_translator-1.11.4-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from vaderSentiment) (2.32.4)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.9.1 in /usr/local/lib/python3.12/dist-packages (from deep-translator) (4.13.5)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4<5.0.0,>=4.9.1->deep-translator) (2.8.4)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4<5.0.0,>=4.9.1->deep-translator) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->vaderSentiment) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->vaderSentiment) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->vaderSentiment) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->vaderSentiment) (2026.5.20)
# Downloading vaderSentiment-3.3.2-py2.py3-none-any.whl (125 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.0/126.0 kB 12.6 MB/s eta 0:00:00
# Downloading deep_translator-1.11.4-py3-none-any.whl (42 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 kB 4.5 MB/s eta 0:00:00
# Installing collected packages: vaderSentiment, deep-translator
# Successfully installed deep-translator-1.11.4 vaderSentiment-3.3.2

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from deep_translator import GoogleTranslator
from tqdm import tqdm

# Inisialisasi SentimentIntensityAnalyzer dan GoogleTranslator
analyzer = SentimentIntensityAnalyzer()
translator = GoogleTranslator(source='id', target='en')

tanyain_teks = df_gojek_test['clean_content'].fillna("").astype(str).tolist()

hasil_terjemahan = []
batch_size = 100

print("Memulai proses translasi berbasis batch...")
for i in tqdm(range(0, len(tanyain_teks), batch_size)):
    batch = tanyain_teks[i:i+batch_size]
    try:
        # Masukkan list berisi 100 teks, hasil outputnya juga list berisi 100 terjemahan
        translated_batch = translator.translate_batch(batch)
        hasil_terjemahan.extend(translated_batch)
    except Exception as e:
        # Jaring pengaman jika satu batch gagal, isi dengan teks kosong agar ukuran list tetap singkron
        hasil_terjemahan.extend([""] * len(batch))
# Out:
# Memulai proses translasi berbasis batch...
# 100%|██████████| 100/100 [17:22<00:00, 10.43s/it]

# %%
def hitung_vader_dari_en(teks_en):
    if not teks_en or teks_en.strip() == "":
        return 'netral'
    scores = analyzer.polarity_scores(teks_en)
    compound = scores['compound']
    if compound >= 0.05: return 'positif'
    elif compound <= -0.05: return 'negatif'
    else: return 'netral'

# Petakan hasil terjemahan langsung ke kolom sentimen
df_gojek_test['sentimen'] = [hitung_vader_dari_en(t) for t in hasil_terjemahan]

# %%
df_gojek_test[['content', 'clean_content', 'sentimen']].head(100)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 content  \
# 0                                                                                                                                                                                                                                                                                                                                                                ga jelas, bertahun-tahun pake tiba-tiba dibilang pelanggaran promo. padahal mereka sendiri yang munculin promo di app di pake malah dibilang melanggar
# 1                                                                                                                                                                                                                                                                                                                                semakin kesini kok lebih parah dari lintah darat. disaat semua kebutuhan naik perawatan kendaraan juga naik tarif ke driver malah turun. semoga Allah memberikan kalian hidayah aamiin
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            kelas king
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 ramah
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             memuaskan
# ..                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# 95                                                                                                                                                                                                                                                                                                                                                                                                                     desain simple gk membingungkan,pelayanan oke,cocok buat siapa aja dan yang pasti BUATAN NEGRI🔥🔥🔥
# 96                                                                                                                                                                                                                                                                                                                                                                                                                                   Ayolah jangan bikin iklan d aplikasi lain yang gk bisa d skip. ganggu banget !!!!!
# 97  Selama ini jujur saya sangat puas dengan gojek, membantu ketika saya bepergian karena saya seringkali bepergian menggunakan umum. tetapi hal menyebalkan terjadi, ketika saya sedang mendengarkan sesuatu diaplikasi lain dan hp saya taruh tas, ntah gimana ceritanya tbtb ada pesanan gofood yg masuk tanpa konfirmasi apapun. gak ada masukan pin atau sejenisnya. saya setelah buka hp tbtb udh ada pesanan. sekarang mau dibatalkan gak bisa, alhasil mau gak mau harus di bayar. Thanks for bad experiencenya
# 98                                                                                                                                                                                                                                                                                                                                                                                                                                                     enak sih kalo mager tinggal pesen aja, tapi ongkirnya kdng mahal
# 99                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  top
#
#                                                                                                                                                                                                                                                                                                 clean_content  \
# 0                                                                                                                                                                                                                    ga bertahun pakai dibilang pelanggaran promo munculin promo app pakai dibilang melanggar
# 1                                                                                                                                                                                               kesini parah lintah darat disaat kebutuhan perawatan kendaraan tarif driver turun semoga allah hidayah aamiin
# 2                                                                                                                                                                                                                                                                                                  kelas king
# 3                                                                                                                                                                                                                                                                                                       ramah
# 4                                                                                                                                                                                                                                                                                                   memuaskan
# ..                                                                                                                                                                                                                                                                                                        ...
# 95                                                                                                                                                                                                                                         desain simple tidak membingungkan pelayanan oke cocok buatan negri
# 96                                                                                                                                                                                                                                                ayolah jangan bikin iklan aplikasi tidak skip ganggu banget
# 97  jujur puas gojek bepergian seringkali bepergian menggunakan menyebalkan mendengarkan diaplikasi hp taruh tas ntah ceritanya tiba tiba pesanan gofood masuk konfirmasi apapun gak masukan pin sejenisnya buka hp tiba tiba udh pesanan dibatalkan gak alhasil gak bayar terima kasih for bad experiencenya
# 98                                                                                                                                                                                                                                                                enak sih mager pesen ongkirnya kadang mahal
# 99                                                                                                                                                                                                                                                                                                        top
#
#    sentimen
# 0   negatif
# 1   positif
# 2    netral
# 3   positif
# 4   positif
# ..      ...
# 95  negatif
# 96  negatif
# 97  negatif
# 98   netral
# 99  positif
#
# [100 rows x 3 columns]

# %%
df_gojek_test['sentimen'].value_counts()
# Out:
# sentimen
# positif    5766
# netral     2350
# negatif    1884
# Name: count, dtype: int64

# %%
df_gojek_test.to_csv('gojek_review_bersih.csv', index=False)
